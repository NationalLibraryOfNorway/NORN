# %%
import pandas as pd
import sys
from norn.config import DATA_BASEPATH
from pymongo import MongoClient
from dataclasses import dataclass
from typing import List, Dict, Any, Optional
from glob import glob
import dhlab as dh
from pathlib import Path
from tqdm.notebook import tqdm

# %%
re_ocr_path = Path("/mnt/md1/new_2023/bok_txt")

# %%
c1800 = pd.read_excel(DATA_BASEPATH / '1800-1839.xlsx')
c1840 = pd.read_excel(DATA_BASEPATH /'1840-1869.xlsx')
kk = pd.read_excel( DATA_BASEPATH / "konsensus-korpus.xlsx")
kka = pd.read_excel( DATA_BASEPATH / "konsensus_korpus_annotert.xlsx")

# %%
db = MongoClient()["norn"]

# %%
@dataclass
class NornText:
    urn: str
    path: str
    korpus: str
    metadata: Dict[str, Any]
    files: list
    text: Optional[str] = None
    
def norn_text_from_korpus_row(row: pd.Series, korpus: str = "c1800") -> NornText:
    urn = row['urn']
    base_urn = urn.split(":")[-1]
    path = str(re_ocr_path / f"{base_urn}")
    #path = row['path']
    #korpus = row['korpus']
    files = sorted(glob(f"{path}/*"))
    metadata = row.to_dict()
    
    if len(files) == 0:
        raise ValueError(f"No files found for {urn} at {path}")
    return NornText(urn, path, korpus, metadata, files)


def get_texts(files: List[str]) -> str:
    txt = ""
    for x in sorted(files):
        with open(x) as f:
            txt += f.read()
            txt += "\n\n"
    return txt

# %%
dhc1800 = dh.Corpus()
dhc1800.extend_from_identifiers(c1800.urn)
assert len(dhc1800.frame) == len(c1800)


dhc1840 = dh.Corpus()
dhc1840.extend_from_identifiers(c1840.urn)
assert len(dhc1840.frame) == len(c1840)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 8
#       6 dhc1840 = dh.Corpus()
#       7 dhc1840.extend_from_identifiers(c1840.urn)
# ----> 8 assert len(dhc1840.frame) == len(c1840)
#
# AssertionError:

# %%
dhkka = dh.Corpus()
dhkka.extend_from_identifiers(kka.urn)
assert len(dhkka.frame) == len(kka)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 dhkka = dh.Corpus()
#       2 dhkka.extend_from_identifiers(kka.urn)
# ----> 3 assert len(dhkka.frame) == len(kka)
#
# AssertionError:

# %%
kka.loc[kka.urn == "URN:NBN:no-nb_digibok_2017020148100"].head(5)
# Out:
#      Kontekst-nasjonalromantisk  Realistisk  Ikke nasjonalromantisk  \
# 15                            2           0                       0
# 39                            2           0                       0
# 41                            0           0                       0
# 101                           1           0                       1
# 124                           0           0                       0
#
#      Nasjonalromantisk  Kontekst-nasjonalromantisk-realisme  \
# 15                   1                                    1
# 39                   0                                    1
# 41                   1                                    0
# 101                  0                                    0
# 124                  1                                    1
#
#      Nasjonalromantisk-realisme                 Verk Forfatter  \
# 15                            0         Blomster-Ole   Moe, J.
# 39                            0            Slædefart   Moe, J.
# 41                            0       Knud og Birgit   Moe, J.
# 101                           0  Sæterjentens søndag   Moe, J.
# 124                           0  Det lysned i Skoven   Moe, J.
#
#                                      urn  Ikke angitt i Lit.Hist.  Samling
# 15   URN:NBN:no-nb_digibok_2017020148100                        0        0
# 39   URN:NBN:no-nb_digibok_2017020148100                        0        0
# 41   URN:NBN:no-nb_digibok_2017020148100                        0        0
# 101  URN:NBN:no-nb_digibok_2017020148100                        0        0
# 124  URN:NBN:no-nb_digibok_2017020148100                        0        0

# %%
c1840.loc[c1840.duplicated(subset=['urn'], keep=False)]
# Out:
#                                     urn
# 3   URN:NBN:no-nb_digibok_2008102912002
# 12  URN:NBN:no-nb_digibok_2008102912002

# %%
dhc1840.frame.loc[dhc1840.frame.urn == "URN:NBN:no-nb_digibok_2008102912002"]
# Out:
#                                     urn      dhlabid  \
# 35  URN:NBN:no-nb_digibok_2008102912002  100628905.0
#
#                                                 title  \
# 35  De tre Bjørne , eller Besøget i Bjørnestuen : ...
#
#                                      authors  \
# 35  Asbjørnsen , P. Chr . ( Peter Christen )
#
#                                   oaiid                           sesamid  \
# 35  oai:nb.bibsys.no:990315083834702202  ab433a503c2bdf18e77d17ed7e08cc3c
#
#    isbn10         city   timestamp    year publisher langs subjects ddc  \
# 35         Christiania  18640101.0  1864.0             nob
#
#    genres   literaryform  doctype ocr_creator  ocr_timestamp
# 35         Uklassifisert  digibok       dhlab     20221209.0

# %%
def update_db(df : pd.DataFrame, korpus: str):
    urns_not_in_reocr = []
    
    for _, row in df.iterrows():
        try:
            norn_text = norn_text_from_korpus_row(row, korpus)
            if len(norn_text.files) == 0:
                print(f"No files found for {norn_text.urn}")
            else:
                norn_text.text = get_texts(norn_text.files)
                
                
                db.norn_texts_temp.insert_one(norn_text.__dict__)
        except ValueError as e:
            print(e)
            print(row['urn'])
            urns_not_in_reocr.append(row['urn'])
            continue
        
    return urns_not_in_reocr

# %%
korpus = {
    "c1800": dhc1800,
    "c1840": dhc1840,
    "kk": dhkka
}

urns_not_in_reocr = []
for key, value in korpus.items():
    e = update_db(value.frame, key)
    urns_not_in_reocr.extend(e)
# Out:
# No files found for URN:NBN:no-nb_digibok_2020022048003 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2020022048003
# URN:NBN:no-nb_digibok_2020022048003
# No files found for URN:NBN:no-nb_digibok_2006120501037 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2006120501037
# URN:NBN:no-nb_digibok_2006120501037
# No files found for URN:NBN:no-nb_digibok_2007110600049 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2007110600049
# URN:NBN:no-nb_digibok_2007110600049
# No files found for URN:NBN:no-nb_digibok_2008040800072 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2008040800072
# URN:NBN:no-nb_digibok_2008040800072
# No files found for URN:NBN:no-nb_digibok_2010061806033 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2010061806033
# URN:NBN:no-nb_digibok_2010061806033
# No files found for URN:NBN:no-nb_digibok_2011040508147 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011040508147
# URN:NBN:no-nb_digibok_2011040508147
# No files found for URN:NBN:no-nb_digibok_2011040508148 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011040508148
# URN:NBN:no-nb_digibok_2011040508148
# No files found for URN:NBN:no-nb_digibok_2011061708062 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011061708062
# URN:NBN:no-nb_digibok_2011061708062
# No files found for URN:NBN:no-nb_digibok_2011061708155 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011061708155
# URN:NBN:no-nb_digibok_2011061708155
# No files found for URN:NBN:no-nb_digibok_2011061708156 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011061708156
# URN:NBN:no-nb_digibok_2011061708156
# No files found for URN:NBN:no-nb_digibok_2011062708033 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011062708033
# URN:NBN:no-nb_digibok_2011062708033
# No files found for URN:NBN:no-nb_digibok_2011091208031 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011091208031
# URN:NBN:no-nb_digibok_2011091208031
# No files found for URN:NBN:no-nb_digibok_2011111605037 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2011111605037
# URN:NBN:no-nb_digibok_2011111605037
# No files found for URN:NBN:no-nb_digibok_2012051805111 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2012051805111
# URN:NBN:no-nb_digibok_2012051805111
# No files found for URN:NBN:no-nb_digibok_2012071305013 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2012071305013
# URN:NBN:no-nb_digibok_2012071305013
# No files found for URN:NBN:no-nb_digibok_2012101507055 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2012101507055
# URN:NBN:no-nb_digibok_2012101507055
# No files found for URN:NBN:no-nb_digibok_2017080207028 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2017080207028
# URN:NBN:no-nb_digibok_2017080207028
# No files found for URN:NBN:no-nb_digibok_2018021948006 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2018021948006
# URN:NBN:no-nb_digibok_2018021948006
# No files found for URN:NBN:no-nb_digibok_2021042048514 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2021042048514
# URN:NBN:no-nb_digibok_2021042048514
# No files found for URN:NBN:no-nb_digibok_2021042148807 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2021042148807
# URN:NBN:no-nb_digibok_2021042148807
# No files found for URN:NBN:no-nb_digibok_2021121448574 at /mnt/md1/new_2023/bok_txt/no-nb_digibok_2021121448574
# URN:NBN:no-nb_digibok_2021121448574
# No files found for URN:NBN:no-nb_digitidsskrift_2014092382073_001 at /mnt/md1/new_2023/bok_txt/no-nb_digitidsskrift_2014092382073_001
# URN:NBN:no-nb_digitidsskrift_2014092382073_001
# No files found for URN:NBN:no-nb_digitidsskrift_2016060981022_001 at /mnt/md1/new_2023/bok_txt/no-nb_digitidsskrift_2016060981022_001
# URN:NBN:no-nb_digitidsskrift_2016060981022_001

# %%
dhc1840.frame.loc[dhc1840.frame.urn.isin(urns_not_in_reocr)].urn.nunique()
# Out:
# 1

# %%
dhc1840.frame.loc[dhc1840.frame.urn.isin(urns_not_in_reocr)]
# Out:
#                                      urn      dhlabid                  title  \
# 226  URN:NBN:no-nb_digibok_2020022048003  100484948.0  Foraarsgave for Damer
#
#                               authors                                oaiid  \
# 226  Monsen , Chr . / Borg , Thorkild  oai:nb.bibsys.no:990313612184702202
#
#                               sesamid isbn10 city   timestamp    year  \
# 226  bef7a63f78fb1b98e6accd652b601c53              18490101.0  1849.0
#
#                    publisher langs          subjects ddc   genres  \
# 226  Trykt hos Thorkild Borg   dan  Norsk litteratur      fiction
#
#          literaryform  doctype ocr_creator  ocr_timestamp
# 226  Skjønnlitteratur  digibok          nb     20060101.0

# %%
dhkka.frame.loc[dhkka.frame.urn.isin(urns_not_in_reocr)].urn.nunique()
# Out:
# 22

# %%
with open("konsensus_urns_not_in_reocr.txt", "w") as f:
    f.write("\n".join(urns_not_in_reocr))

# %%
c = dh.Corpus()
c.extend_from_identifiers(urns_not_in_reocr)
c.sort("year")
# Out:
#                                                urn      dhlabid  \
# 20             URN:NBN:no-nb_digibok_2021121448574  100604100.0
# 12             URN:NBN:no-nb_digibok_2012051805111  100071871.0
# 9              URN:NBN:no-nb_digibok_2011062708033  100544647.0
# 6              URN:NBN:no-nb_digibok_2011061708062  100542693.0
# 10             URN:NBN:no-nb_digibok_2011091208031  100055374.0
# 8              URN:NBN:no-nb_digibok_2011061708156  100542769.0
# 7              URN:NBN:no-nb_digibok_2011061708155  100542768.0
# 5              URN:NBN:no-nb_digibok_2011040508148  100538545.0
# 4              URN:NBN:no-nb_digibok_2011040508147  100535717.0
# 19             URN:NBN:no-nb_digibok_2021042148807  100440317.0
# 1              URN:NBN:no-nb_digibok_2007110600049  100500833.0
# 16             URN:NBN:no-nb_digibok_2018021948006  100364575.0
# 11             URN:NBN:no-nb_digibok_2011111605037  100070895.0
# 13             URN:NBN:no-nb_digibok_2012071305013  100102006.0
# 3              URN:NBN:no-nb_digibok_2010061806033  100008225.0
# 18             URN:NBN:no-nb_digibok_2021042048514  100584416.0
# 0              URN:NBN:no-nb_digibok_2006120501037  100569912.0
# 2              URN:NBN:no-nb_digibok_2008040800072  100481031.0
# 21  URN:NBN:no-nb_digitidsskrift_2014092382073_001  300186128.0
# 14             URN:NBN:no-nb_digibok_2012101507055  100114358.0
# 15             URN:NBN:no-nb_digibok_2017080207028  100346794.0
# 17             URN:NBN:no-nb_digibok_2020022048003  100484948.0
# 22  URN:NBN:no-nb_digitidsskrift_2016060981022_001  300149622.0
#
#                                                 title  \
# 20                                             Salmer
# 12             Henrik Ibsens skrifter . 16 : Sakprosa
# 9                  Henrik Ibsens skrifter . 11 : Dikt
# 6   Henrik Ibsens skrifter . 4 : Svanhild ; Kjærli...
# 10  Henrik Ibsens skrifter . 5 : Episk Brand ( 186...
# 8   Henrik Ibsens skrifter . 3 : Fru Inger til Øst...
# 7   Henrik Ibsens skrifter . 2 : Gildet paa Solhou...
# 5        Henrik Ibsens skrifter . 12 : Brev 1844-1871
# 4   Henrik Ibsens skrifter . 1 : Catilina ( 1850 )...
# 19              Norsk tro og tanke . B. 2 : 1800-1940
# 1                 Sunnmørsgrammatikkane av Ivar Aasen
# 16                        Andhrimner : ( " Manden " )
# 11  Ny Samling af norske Ord og Talemaader , 1806-...
# 13                   Ervingen : songspel i ei vending
# 3                                             Dikting
# 18               Symra : tvo tylfter med visor og rim
# 0   Reise-Erindringer og Reise-Indberetninger 1842...
# 2            Skrifter i samling : trykt og utrykt . 3
# 21          Syn & segn ( trykt utg. ) . 1909 Vol . 15
# 14                        Samlede Digterverker . B. 3
# 15                       Til og fra Amerika : Skizzer
# 17                              Foraarsgave for Damer
# 22  Annaler for Nordisk Oldkyndighed og Historie ....
#
#                                               authors  \
# 20  Landstad , M. B. / Baklid , Herleik / Haavik ,...
# 12  Ibsen , Henrik / Janss , Christian / Ystad , V...
# 9   Ibsen , Henrik / Ystad , Vigdis / Janss , Chri...
# 6                     Ibsen , Henrik / Ystad , Vigdis
# 10                    Ibsen , Henrik / Ystad , Vigdis
# 8   Ibsen , Henrik / Ystad , Vigdis / Janss , Chri...
# 7                     Ibsen , Henrik / Ystad , Vigdis
# 5   Ibsen , Henrik / Ystad , Vigdis / Fulsås , Nar...
# 4   Ibsen , Henrik / Ystad , Vigdis / Janss , Chri...
# 19
# 1   Aasen , Ivar / Nes , Oddvar / Aarset , Terje /...
# 16  Botten-Hansen , Paul / Ibsen , Henrik / Vinje ...
# 11                            Lundh , Gregers Fougner
# 13                       Aasen , Ivar / Thorson , Per
# 3                                        Aasen , Ivar
# 18                                       Aasen , Ivar
# 0                       Aasen , Ivar / Koht , Halvdan
# 2                                        Aasen , Ivar
# 21
# 14               Welhaven , J. S. ( Johan Sebastian )
# 15              Meltzer , H. / Bloch , A. ( Andreas )
# 17                   Monsen , Chr . / Borg , Thorkild
# 22
#
#                                                 oaiid  \
# 20                oai:nb.bibsys.no:999920079479002202
# 12                oai:nb.bibsys.no:991119062104702202
# 9                 oai:nb.bibsys.no:991002464354702202
# 6                 oai:nb.bibsys.no:990801754144702202
# 10                oai:nb.bibsys.no:990707950454702202
# 8                 oai:nb.bibsys.no:990610088004702202
# 7                 oai:nb.bibsys.no:990609739194702202
# 5                 oai:nb.bibsys.no:990601518034702202
# 4                 oai:nb.bibsys.no:990600822164702202
# 19                oai:nb.bibsys.no:999825325634702202
# 1                 oai:nb.bibsys.no:999205389404702202
# 16                oai:nb.bibsys.no:999111845204702202
# 11                oai:nb.bibsys.no:998020087044702202
# 13                oai:nb.bibsys.no:999404785954702202
# 3                 oai:nb.bibsys.no:997521390884702202
# 18                oai:nb.bibsys.no:999421293004702202
# 0                 oai:nb.bibsys.no:999406910864702202
# 2                 oai:nb.bibsys.no:999317126964702202
# 21  oai:urn.nb.no:no-nb_digitidsskrift_20140923820...
# 14                oai:nb.bibsys.no:999316331414702202
# 15                oai:nb.bibsys.no:998121224534702202
# 17                oai:nb.bibsys.no:990313612184702202
# 22  oai:urn.nb.no:no-nb_digitidsskrift_20160609810...
#
#                              sesamid                                isbn10  \
# 20  ebcbd7c60f2d7e8d66cfb35d4b8d2019
# 12  71f9e6f983531e8293c9eff8a34ec28e
# 9   0b00adf4dbd448568e5874ae5f9d81ae
# 6   ef963a4d7ad20d96d8a881f2d6c70108  8203189547 / 8203189636 / 8203189814
# 10  7397db0c8a04ba3a83a34f063fc0ba1b  8203189881 / 8203190022 / 8203189814
# 8   108b42e66b6a6f96ee06404a2e91b75c  8203189598 / 8203190014 / 8203189814
# 7   9bde2e808695a8a6c04a74dccef77a88  8203189571 / 8203190006 / 8203189814
# 5   f3b9cddaf8a1837af19e04e5dbe34fb0  8203190103 / 8203189458 / 8203189814
# 4   b7ad880c0370c04e8229b732c1544f26  8203189555 / 8203189849 / 8203189814
# 19  a51aed33dd72398bf66315f6def736d2  8215001726 / 8251838118 / 8251838096
# 1   b1bfb2f745e00a8ff4a49c44cda14e10               8290186827 / 8290186835
# 16  1c5ffb3e5eee3a03f4de0249554972b8
# 11  58f29596635cf811f633b31889095181
# 13  f647cff9ad49f185b50041027ce3136b
# 3   0edec29461cda820a838d0e139e9d00c
# 18  e5d0a398b2137c6061748a46c3d6b675
# 0   ed755af21a68c18bbd23a57626a5935b
# 2   286a08a16e771941bad64e12b58e7fab
# 21  f7acf7fe3dcfecd6baa2324d1d634692
# 14  31789277529cdfeebea8b1b0ae5c6315
# 15  840beba546ae95094c2e149811896e96
# 17  bef7a63f78fb1b98e6accd652b601c53
# 22  6b524d2f7c9d448401435c44cd92ed22
#
#           city   timestamp    year                               publisher  \
# 20                  2020.0  2020.0                            Novus forlag
# 12        Oslo  20100101.0  2010.0                  [Universitetet i Oslo]
# 9         Oslo  20090101.0  2009.0                  [Universitetet i Oslo]
# 6         Oslo  20080101.0  2008.0                  [Universitetet i Oslo]
# 10        Oslo  20070101.0  2007.0                  [Universitetet i Oslo]
# 8         Oslo  20060101.0  2006.0                  [Universitetet i Oslo]
# 7         Oslo  20060101.0  2006.0                  [Universitetet i Oslo]
# 5         Oslo  20050101.0  2005.0                  [Universitetet i Oslo]
# 4         Oslo  20050101.0  2005.0                  [Universitetet i Oslo]
# 19              19980101.0  1998.0                          Tano Aschehoug
# 1               19920101.0  1992.0                               Selskapet
# 16        Oslo  19570101.0  1957.0                   Hovedkommisjon: Tanum
# 11        Oslo  19540101.0  1954.0                                  [s.n.]
# 13        Oslo  19490101.0  1949.0                               Gyldendal
# 3         Oslo  19460101.0  1946.0                               Gyldendal
# 18  Kristiania      1922.0  1922.0                  Gyldendalske Bokhandel
# 0    Trondhjem  19170101.0  1917.0                                  [s.n.]
# 2   Kristiania  19120101.0  1912.0  Gyldendalske Boghandel, Nordisk Forlag
# 21        Oslo      1909.0  1909.0                                Samlaget
# 14  Kristiania  19070101.0  1907.0                  Gyldendalske Boghandel
# 15  Kristiania  19070101.0  1907.0                             Cammermeyer
# 17              18490101.0  1849.0                 Trykt hos Thorkild Borg
# 22  Kjøbenhavn      1846.0  1846.0                               Selskabet
#
#                     langs                                           subjects  \
# 20                    nob  Salmer / Kulturhistorie / Kulturhistorie / Fol...
# 12                    nob           norske / skuespill / 1800-tallet / drama
# 9                     nob           norske / skuespill / 1800-tallet / drama
# 6                     nob           norske / skuespill / 1800-tallet / drama
# 10                    nob           norske / skuespill / 1800-tallet / drama
# 8                     nob                   norske / skuespill / 1850-tallet
# 7                     nob                                 norske / skuespill
# 5                     nob           norske / skuespill / 1800-tallet / drama
# 4                     nob           norske / skuespill / 1800-tallet / drama
# 19  mul / nob / nno / dan  Mentalitet / Historisk framstilling / Religiøs...
# 1                     nno  Norsk språk / Sunnmørsmål / Grammatikk / Diale...
# 16                    nob
# 11        mul / nno / nob  norske / ord / talemål / norsk / språk / diale...
# 13                    nno  norsk / nynorsk / litteratur / skjønnlitteratu...
# 3         mul / nob / nno  nynorsk / norsk / litteratur / 1800-tallet/ii ...
# 18                    nno  norsk / nynorsk / språk / litteratur / skjønnl...
# 0                     nob  Norsk språk / Dialekter / Reiser / Norge / Nor...
# 2                     nno               norsk / nynorsk / litteratur / språk
# 21                    nno  Nynorsk språk / Norsk litteratur / Kultur / No...
# 14                    nob
# 15                    nob  Amerikabrev / Emigranthistorie / Indianere / P...
# 17                    dan                                   Norsk litteratur
# 22                    dan  Norden / Danmark / Årbøker / Historie / Arkeol...
#
#                           ddc                            genres  \
# 20                     264.23  bibliography / biography / tekst
# 12          839.82s / 839.822                           fiction
# 9                     829.822                            poetry
# 6           839.82s / 839.822                             drama
# 10                    839.822                           fiction
# 8                     839.822                           fiction
# 7                     839.822                           fiction
# 5                     839.822                            letter
# 4                     839.822                           fiction
# 19                      948.1
# 1   439.82739 / 439.827948391
# 16                      058.1
# 11
# 13
# 3
# 18
# 0
# 2
# 21                                                   periodical
# 14                                                       poetry
# 15
# 17                                                      fiction
# 22
#
#         literaryform         doctype ocr_creator  ocr_timestamp
# 20     Faglitteratur         digibok          nb     20060101.0
# 12  Skjønnlitteratur         digibok          nb     20060101.0
# 9   Skjønnlitteratur         digibok          nb     20060101.0
# 6   Skjønnlitteratur         digibok          nb     20060101.0
# 10  Skjønnlitteratur         digibok          nb     20060101.0
# 8   Skjønnlitteratur         digibok          nb     20060101.0
# 7   Skjønnlitteratur         digibok          nb     20060101.0
# 5      Faglitteratur         digibok          nb     20060101.0
# 4   Skjønnlitteratur         digibok          nb     20060101.0
# 19     Faglitteratur         digibok          nb     20060101.0
# 1      Faglitteratur         digibok          nb     20060101.0
# 16     Faglitteratur         digibok          nb     20060101.0
# 11     Uklassifisert         digibok          nb     20060101.0
# 13     Uklassifisert         digibok          nb     20060101.0
# 3      Uklassifisert         digibok          nb     20060101.0
# 18     Uklassifisert         digibok          nb     20060101.0
# 0      Uklassifisert         digibok          nb     20060101.0
# 2      Uklassifisert         digibok          nb     20060101.0
# 21     Uklassifisert  digitidsskrift          nb     20060101.0
# 14  Skjønnlitteratur         digibok          nb     20060101.0
# 15     Uklassifisert         digibok          nb     20060101.0
# 17  Skjønnlitteratur         digibok          nb     20060101.0
# 22     Uklassifisert  digitidsskrift          nb     20060101.0

# %%
c.to_csv("konsensus_urns_not_in_reocr.csv")
